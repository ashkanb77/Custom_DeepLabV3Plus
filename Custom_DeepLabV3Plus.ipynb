# %% [markdown]
# <a href="https://colab.research.google.com/github/ashkanb77/Custom_DeepLabV3Plus/blob/main/Custom_DeepLabV3Plus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip -q install torchmetrics
# Out:
#      |████████████████████████████████| 419 kB 9.5 MB/s

# %%
! git clone https://github.com/ashkanb77/Custom_DeepLabV3Plus.git
# Out:
# Cloning into 'Custom_DeepLabV3Plus'...
# remote: Enumerating objects: 40, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 40 (delta 0), reused 0 (delta 0), pack-reused 37
# Unpacking objects: 100% (40/40), done.

# %%
cd Custom_DeepLabV3Plus
# Out:
# /content/Custom_DeepLabV3Plus

# %%
# !git clone https://github.com/NVIDIA/apex
# Out:
# Cloning into 'apex'...
# remote: Enumerating objects: 10388, done.
# remote: Counting objects: 100% (490/490), done.
# remote: Compressing objects: 100% (310/310), done.
# remote: Total 10388 (delta 264), reused 346 (delta 167), pack-reused 9898
# Receiving objects: 100% (10388/10388), 15.11 MiB | 13.92 MiB/s, done.
# Resolving deltas: 100% (7071/7071), done.

# %%
cd apex
# Out:
# /content/Custom_DeepLabV3Plus/apex

# %%
# !pip install -v -q --disable-pip-version-check --no-cache-dir ./
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing /content/Custom_DeepLabV3Plus/apex
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
# ...
#   Created wheel for apex: filename=apex-0.1-py3-none-any.whl size=339843 sha256=807fe69b144903eb711d5230d7b86dbf67c178a39a7f0124a2386dd4ef89621b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-03u6h57m/wheels/76/56/06/29aea29bc4df4e0852110d22cd7759eb2acb54a5f9f5246489
# Successfully built apex
# ...

# %%
cd ..
# Out:
# /content/Custom_DeepLabV3Plus

# %%
! pip -q install ml_collections
# Out:
#      |████████████████████████████████| 77 kB 4.1 MB/s
# ...

# %%
import albumentations as A
from dataset import VOCSeg
from config import *
from utils import visualize, plot_images

# %%
transform = A.Compose([
        A.Resize(IMAGE_SIZE + 30, IMAGE_SIZE + 30),
        A.RandomCrop(IMAGE_SIZE, IMAGE_SIZE),
        A.HorizontalFlip(p=0.5),
        A.Rotate(limit=(-20, 20)),
        A.VerticalFlip(p=0.5),
])


dataset = VOCSeg(
    'dataset', download=True, image_set='train',
     transforms=transform,
     )
# Out:
# ...
#   0%|          | 0/1999639040 [00:00<?, ?it/s]
# Extracting dataset/VOCtrainval_11-May-2012.tar to dataset

# %%
image, mask = dataset[0]
visualize(image, mask)

# %%
plot_images(dataset)

# %%
# %run train.py --n_epochs 120
# Out:
# Using downloaded and verified file: dataset/VOCtrainval_11-May-2012.tar
# Extracting dataset/VOCtrainval_11-May-2012.tar to dataset
# Selected optimization level O1:  Insert automatic casts around Pytorch functions and Tensor methods.
#
# Defaults for this optimization level are:
# enabled                : True
# opt_level              : O1
# cast_model_type        : None
# patch_torch_functions  : True
# keep_batchnorm_fp32    : None
# master_weights         : None
# loss_scale             : dynamic
# Processing user overrides (additional kwargs that are not None)...
# After processing overrides, optimization options are:
# enabled                : True
# opt_level              : O1
# cast_model_type        : None
# patch_torch_functions  : True
# keep_batchnorm_fp32    : None
# master_weights         : None
# loss_scale             : dynamic
# Epoch 1: 100%|██████████| 46/46 [00:41<00:00,  1.11batch/s, MIOU=0.0784, loss=1.19]
# ...

# %% [markdown]
# need more training

# %%
# %run test.py --image_path 'dataset/VOCdevkit/VOC2012/JPEGImages/2007_000027.jpg' --checkpoint_path 'checkpoints/DeepLabV3Plus.pth'

# %%
from PIL import Image
Image.open('dataset/VOCdevkit/VOC2012/JPEGImages/2007_000027.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=486x500 at 0x7F483EEA4E10>
